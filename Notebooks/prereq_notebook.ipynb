# %%
print("Hello, Data Analysis")
# Out:
# Hello, Data Analysis

# %%
print("I am Swathi. Iam very excited to learn Python.")
# Out:
# I am Swathi. Iam very excited to learn Python.

# %%
print("Thank you team for givimng me this opportunity")
# Out:
# Thank you team for givimng me this opportunity
